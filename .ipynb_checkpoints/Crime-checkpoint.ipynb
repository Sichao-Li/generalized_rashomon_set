# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from utilities import *
from visulizer import *
from feature_interaction_helper import *
from feature_importance_helper import *
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: sklearn.tree._splitter.Splitter size changed, may indicate binary incompatibility. Expected 360 from C header, got 1160 from PyObject

# %%
data = pd.read_csv('compas.csv', usecols=['Age=18-20', 'Race=African-American', 'Prior-Crimes=0','Gender=Male', 'Juvenile-Crimes=0', 'Current-Charge-Degree=Misdemeanor'])
X = data.rename({'Age=18-20':"age", 'Race=African-American':"race", 'Prior-Crimes=0':"prior", 'Gender=Male':"gender", 'Juvenile-Crimes=0':"juvenilecrime", 'Current-Charge-Degree=Misdemeanor':"currentcharge"}, axis='columns')
y = pd.read_csv('compas.csv', usecols=['Recidivate-Within-Two-Years'])
# y[y==0] = -1
vlist = ["age", "race", "prior", "gender", "juvenilecrime", "currentcharge"]
# vlist = ["age", "race", "prior", "gender"]
X = X[vlist]
y = y.to_numpy().reshape(len(y))

mu, sigma = 0, 0.1 
noise = np.random.normal(mu, sigma, np.shape(X))
X_noise = X + noise
X_new = pd.concat([X_noise, X])
y_new = np.concatenate([y,y])


# X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, random_state = 2023, test_size=0.7)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2023, test_size=0.7)

# model = LogisticRegression(solver='liblinear').fit(X_train, y_train)
model = sm.Logit(y_train, sm.add_constant(X_train)).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.638726
#          Iterations 6

# %%
# loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(X_test), regression=False)
loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(sm.add_constant(X_test)),epsilon=0.5, regression=False)
loss0, bound_f, bound_f_half
# Out:
# (6.412213966205562e-01, 0.3206106983102781, 0.16030534915513905)

# %%
vt_f, points_all_max, points_all_min =find_VT(bound_f, loss0, vlist, model, X_test, y_test, delta=0.1, regression=False)

# %%
# def shuffle_loss(X_i, feature_idx, comb, model, model):
#     X_i.iloc[:, feature_idx[0]] = X_i.iloc[:, feature_idx[0]]*comb[0]
#     X_i_shuffle = X_i.copy()
#     for idx in feature_idx:
#         np.random.shuffle(X0_shuffle.iloc[:, idx].values)
#     pred_shuffle = model.predict(sm.add_constant(X0_shuffle))
#     myloss_shuffle = loss_regression(y, pred_shuffle)
#     return myloss_shuffle 


def Interaction_effect_calculation(feature_idx, model, e_idx, vt_f, X, y, loss0, boundary, regression=True):
    '''
    Calculate the feature interaction effect following 
    c(x1, x2) = c(x1) + c(x2) + fi(x1, x2) wrt. c(x1) + c(x2) = boundary
    fi(x1, x2) is defined as the difference between boundary and emperical loss.
    The value of fi(x1, f2) can be negative or positive.
    
        Input:
            feature_idx: features to be calculated
            model: optimal model
            e_idx: pairs that sum to one index
            vt_f: variance tolerance for all features
            X: input data
            loss0: optimal loss
            boundary: pre-defined boundary for R set
        Output:
            loss_emp: emperical loss set
            diff: feature interaction value set
    '''
    feature_interest = np.array(vt_f)[(feature_idx), :, :]
    possibilities = []
    loss_emp = []
    diff = []
    shuffle_values = []

    for idx, i in enumerate(e_idx):
        possibilities.append(feature_interest[idx, i, :])
    for comb in itertools.product(*possibilities):
        X0 = X.copy()
        X_i = X.copy()
        X_j = X.copy()
        if isinstance(X, pd.DataFrame):
            X0.iloc[:, feature_idx] = X0.iloc[:, feature_idx]*comb
            X0_shuffle = X0.copy()
            
            X_i.iloc[:, feature_idx[0]] = X_i.iloc[:, feature_idx[0]]*comb[0]
            X_i_shuffle = X_i.copy()
            
            np.random.shuffle(X_i_shuffle.iloc[:, feature_idx[0]].values)
            X_j.iloc[:, feature_idx[-1]] = X_j.iloc[:, feature_idx[-1]]*comb[-1]
            X_j_shuffle = X_j.copy()
            np.random.shuffle(X_j_shuffle.iloc[:, feature_idx[-1]].values)            
            
            for idx in feature_idx:
                np.random.shuffle(X0_shuffle.iloc[:, idx].values)
#             print(X0_shuffle, X0)
            
        else:
            X0[:,feature_idx] = X0[:,feature_idx]*comb
            X0_shuffle = X0.copy()
            np.random.shuffle(X0_shuffle[:,feature_idx])
        if hasattr(model, 'model'):
            pred = model.predict(sm.add_constant(X0))
#                 if isinstance(model, sm.Logit):
            pred_shuffle = model.predict(sm.add_constant(X0_shuffle))
    
            pred_i = model.predict(sm.add_constant(X_i))
#                 if isinstance(model, sm.Logit):
            pred_i_shuffle = model.predict(sm.add_constant(X_i_shuffle))
            pred_j = model.predict(sm.add_constant(X_j))
#                 if isinstance(model, sm.Logit):
            pred_j_shuffle = model.predict(sm.add_constant(X_j_shuffle))
        else:
            pred = model.predict(X0)
            pred_shuffle = model.predict(X0_shuffle)
        if regression:
            myloss = loss_regression(y, pred)
            myloss_shuffle = loss_regression(y, pred_shuffle)
            mylos_i = loss_regression(y, pred_i)
            myloss_i_shuffle = loss_regression(y, pred_i_shuffle)
            myloss_j = loss_regression(y, pred_j)
            myloss_j_shuffle = loss_regression(y, pred_j_shuffle)
            I_ij = myloss - myloss_shuffle
            I_i = myloss_i - myloss_i_shuffle
            I_j = myloss_j - myloss_j_shuffle
        else:
            myloss = log_loss(y, pred)
            myloss_shuffle = log_loss(y, pred_shuffle)
            myloss_i = log_loss(y, pred_i)
            myloss_i_shuffle = log_loss(y, pred_i_shuffle)
            myloss_j = log_loss(y, pred_j)
            myloss_j_shuffle = log_loss(y, pred_j_shuffle)
            I_ij = myloss_shuffle / myloss 
            I_i = myloss_i_shuffle / myloss_i
            I_j = myloss_j_shuffle / myloss_j
#         M_I
        shuffle_values.append([I_i, I_j, I_ij])
        mydiff = myloss-loss0-boundary
        diff.append((mydiff))
        loss_emp.append((myloss))
    return diff, loss_emp, shuffle_values

def Interaction_effect_all_pairs(X, y, vlist, n_ways, model, vt_f, loss0, boundary, regression=True):
    '''
    Calculate the feature interaction effect for all pairs.
        Input:
            X: input data
            vlist: variable list
            n_ways: an integer that defines the number of joint features
            model: optimal model
            vt_f: variance tolerance for all features
            loss0: optimal loss
            boundary: pre-defined boundary for R set
        Output:
            myloss_all: emperical loss set for all features
            diff_all: feature interaction value set for all features
    '''
    all_n_way_feature_pairs = find_all_n_way_feature_pairs(vlist, n_ways)
    all_sum_to_one_pairs = find_all_sum_to_one_pairs(n_ways)
    diff_all = []
    myloss_all = []
    shuffle_values_all = []
    for pair in all_n_way_feature_pairs:
    # for each pair, find interaction effect and loss
        fi = []
        loss = []
        shuffle = []
        if pair[0] != 0:
            pair = np.nonzero(np.in1d(vlist, pair))[0]
        for sum_to_one_pair in all_sum_to_one_pairs:
        # each pair has n^2 possibilities
            diff, myloss, shuffle_values = Interaction_effect_calculation(pair, model, sum_to_one_pair, vt_f, X, y, loss0, boundary, regression=regression)
            fi =  diff + fi
            loss =  myloss + loss
            shuffle = shuffle_values + shuffle
        myloss_all.append(loss)
        diff_all.append(fi)
        shuffle_values_all.append(shuffle)
    return myloss_all, diff_all, shuffle_values_all

# %%
vt_f_baseline = np.ones((6,11,2))
Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_f_baseline, loss0, bound_f, regression=False)
# Out:
# (1.0258558168041563e+00, 1.0157823372664843) 1.035538252777604
# (1.0280993454863132e+00, 1.0152516660937416) 1.0282385997091925
# (1.0270775766312057e+00, 1.016307018427067) 1.0375441690115972
# (1.0213827990782391e+00, 1.0143938716879126) 1.0432549822800197
# (1.0246367015276234e+00, 1.0178630929424717) 1.0360609629321595
# (1.023914175466078e+00, 1.0177456071141193) 1.041070470761969
# (1.0267962984489878e+00, 1.01373096414841) 1.0431969188707613
# (1.0278416915482818e+00, 1.015815308014208) 1.0395936033062625
# (1.0215254019071476e+00, 1.0125447710424684) 1.0346531421273741
# (1.025033897234312e+00, 1.017431082577717) 1.039578559996655
# (1.0284640313986295e+00, 1.0173409849860982) 1.0390723849228642
# (1.0287022520614006e+00, 1.018591626508323) 1.038664465724106
# (1.0296023441851614e+00, 1.0125474609113772) 1.0373158511801044
# (1.023289791389764e+00, 1.019418133319787) 1.0442255058169883
# (1.0270216106263763e+00, 1.0146857857237217) 1.04788077234601
# ...

# %%
Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_f, loss0, bound_f, regression=False)
# Out:
# 2.3539803662977334e+00 1.3767568642955734
# 2.2384852426848285e+00 1.3126439197310762
# 1.9435765078844178e+00 0.9388378622404558
# 1.8207885768606837e+00 0.8695203784619817
# 2.4394100472011955e+00 1.3194759884516754
# 2.295934358907367e+00 1.1170956362860265
# 1.999277385045191e+00 1.008434670999505
# 1.8648283008630346e+00 0.8949795863954977
# 2.4629544426293e+00 1.3457930705137264
# 2.3324307941942104e+00 1.2078287382370831
# 1.9947594599204452e+00 0.9844647046253704
# 1.8673842221121653e+00 0.8903974458878924
# 2.3698534899899357e+00 1.3001775883482063
# 2.2688849803517086e+00 1.30438134279368
# 1.9605705386727015e+00 0.9424045210638717
# 1.8078686832230058e+00 0.8433770077802573
# 2.4687100969232905e+00 1.3168181022117689
# 2.3315713387359076e+00 1.2476100565510522
# 1.9077623357493174e+00 0.9194060541032455
# 1.8069213659805325e+00 0.8510937527406309
# 2.37787873851014e+00 1.2963952970125685
# 2.2512995810202523e+00 1.2848776630565055
# 1.913866864277498e+00 0.901811662785271
# ...

# %%
vt_fi=scores_under_score_function(vt_f, vlist, model, X_test, y_test)

# %%
epsilon_vs_score_vs_m(vlist, vt_fi, vt_f)

# %%
epsilon_vs_score_vs_m_3D(vlist, vt_fi, vt_f)

# %%
m_training_process_vis(points_all_max, points_all_min, vlist)
# Out:
# /home/sichao/Documents/Projects/feature-importance-master/vic-v1.0.0/Jiayun-Dong-vic-47db024/visulizer.py:40: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   points_all = [np.array(points_all_max)[:,-1][i]+np.array(points_all_min)[:,-1][i] for i, idx in enumerate(range(len(points_all_min))[::-1])]

# %%
# find 15 pairs with 36 different interactions
myloss_all_2, diff_all_2 = Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_f, loss0, bound_f, regression=False)
# myloss_all_3, diff_all_3 = Interaction_effect_all_pairs(X_test, y_test, vlist, 3, model, vt_f, loss0, bound_f, regression=False)

# %%
fi_std = feature_importance(vt_fi)

# %%
import matplotlib.pyplot as plt
plt.bar(vlist,fi_std)
# plt.xticks(range(len(model.feature_importances_)), train_features.columns)
plt.show()

# %%
import statsmodels.api as sm
from sklearn.base import BaseEstimator, RegressorMixin

class SMWrapper(BaseEstimator, RegressorMixin):
    """ A universal sklearn-style wrapper for statsmodels regressors """
    def __init__(self, model_class, fit_intercept=True):
        self.model_class = model_class
        self.fit_intercept = fit_intercept
    def fit(self, X, y):
        if self.fit_intercept:
            X = sm.add_constant(X)
        self.model_ = self.model_class(y, X)
        self.results_ = self.model_.fit()
        return self
    def predict(self, X):
        if self.fit_intercept:
            X = sm.add_constant(X)
        return self.results_.predict(X)

# %%
model = SMWrapper(sm.Logit)
model = model.fit(sm.add_constant(X_train), y_train)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.638726
#          Iterations 6

# %%
from sklearn.inspection import partial_dependence

univariate = {}
for i in vlist:
    univariate[i] = partial_dependence(model, sm.add_constant(X_test), features=[i], kind='average')['average']
    
bivariate = {}
for i, j in itertools.combinations(vlist,2):
    bivariate[(i, j)] = partial_dependence(model, sm.add_constant(X_test), features=[i, j], kind='average')['average']

# %%
h = np.zeros((len(vlist), len(vlist)))
for i, j in itertools.combinations(vlist, 2):
    iidx = np.nonzero(np.in1d(vlist, i))[0]
    jidx = np.nonzero(np.in1d(vlist, j))[0]
    h[iidx, jidx] = np.sum(np.square(bivariate[(i, j)] - univariate[i].reshape(1, -1, 1) - univariate[j].reshape(1, 1, -1) )) / np.sum(np.square(bivariate[(i, j)]))
#     h[i, j] = np.sum(np.square(bivariate[(i, j)] - univariate[i].reshape(1, -1, 1) - univariate[j].reshape(1, 1, -1))) / np.sum(np.square(bivariate[(i, j)]))

h
# Out:
# array([[0.        , 0.50311387, 0.52275638, 0.51902192, 0.4788624 ,
#         0.51060233],
#        [0.        , 0.        , 1.12510563, 1.06936913, 0.75817097,
#         1.01818743],
#        [0.        , 0.        , 0.        , 1.22732703, 0.85674942,
#         1.1674099 ],
#        [0.        , 0.        , 0.        , 0.        , 0.81462601,
#         1.10804129],
#        [0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.7805002 ],
#        [0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        ]])

# %%
from sklearn.inspection import plot_partial_dependence
plot_partial_dependence(model, sm.add_constant(X_train), vlist)

# %%
from sklearn.inspection import partial_dependence
# PDP feature importance by Brandon
VI_pdp = []

for vname in vlist:
    crime_pd=partial_dependence(model, features=[vname], X=sm.add_constant(X_train))['average'][0]
    VI_pdp.append((np.max(crime_pd)-np.min(crime_pd))/4)
plt.bar(vlist, VI_pdp)
# plt.xticks(range(len(model.feature_importances_)), train_features.columns)
plt.show()

# %%
vt_d1_sum = np.sum(vt_f[:,1:,:] - vt_f[:,:-1,:], axis=1)
vt_d1_sum
# Out:
# array([[ 2.6461, -1.4539],
#        [ 1.475 , -1.4452],
#        [ 1.2584, -1.1076],
#        [ 2.1966, -2.1954],
#        [ 0.7143, -0.6991],
#        [ 4.3667, -4.1632]])

# %%
# strength, cor_test_3, circle_test_3, _ = feature_interaction_strength(diff_all_3, myloss_all_3, 3, bound_f, 0, loss0)
strength, cor_test_2, circle_test_2, _ = feature_interaction_strength(diff_all_2, myloss_all_2, 2, bound_f, 0, loss0)

# %%
# plot of data in 3D
import matplotlib.cm as cm
def feature_interaction_vis_3D(ball_exp, ball_emp):
    ax = plt.axes(projection='3d')
    ball_exp = np.array(ball_exp)
    ball_emp = np.array(ball_emp)
    ax.scatter(ball_exp[:,0], ball_exp[:,1], ball_exp[:,2], alpha=.5)
    ax.scatter(ball_emp[:,0], ball_emp[:,1], ball_emp[:,2], alpha=.5)
#     ax.view_init(elev=60)
feature_interaction_vis_3D(circle_test_3, cor_test_3)

# %%
from sklearn.inspection import permutation_importance
r = permutation_importance(model, sm.add_constant(X_test), y_test,n_repeats=30,random_state=0)

# %%
rr=[]
for idx, i in enumerate(vlist):
    for j in range(len(vt_f[0])):
        X0=X_test.copy()
        X0[i] = X0[i]*vt_f[idx,j,0]
        r0=permutation_importance(model, sm.add_constant(X0), y_test,n_repeats=10,random_state=0)
        rr.append(r0.importances_mean[1:])
        X0=X_test.copy()
        X0[i] = X0[i]*vt_f[idx,j,1]
        r1=permutation_importance(model, sm.add_constant(X0), y_test,n_repeats=5,random_state=0)
        rr.append(r1.importances_mean[1:])

# %%
r.importances_mean

# %%
np.min(rr, axis=0)

# %%
np.max(rr, axis=0)

# %%
plt.bar(vlist,r.importances_mean[1:])
# plt.xticks(range(len(model.feature_importances_)), train_features.columns)
plt.show()

# %%
e_all_new=[]
vt_all_set = []
for e in [0.01, 0.015, 0.02, 0.05, 0.1, 0.15, 0.2, 0.3, 0.5, 1]:
    loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(sm.add_constant(X_test)),epsilon=e, regression=False)
    vt_f, points_all_max, points_all_min =find_VT(bound_f, loss0, vlist, model, X_test, y_test, delta=0.1, regression=False)
    vt_all_set.append(vt_f)
    myloss_all_2, diff_all_2 = Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_f, loss0, bound_f, regression=False)
    strength, cor_test_2, circle_test_2, ratio = feature_interaction_strength(diff_all_2, myloss_all_2, 2, bound_f, 0, loss0)
    e_all_new.append((strength, cor_test_2, circle_test_2, ratio))

# %%
def feature_interaction_strength(emp_diff, myloss_all, n_ways, boundary, pair_idx, loss0):
    '''
    amount is approximated by the area of a circle - delta*(emp_diff+exp_diff)
    
        Input: 
            emp_diff: calculated difference
            n_ways: number of ways
            boundary: pre-defined boundary
        Output:
            the feature interaction strength
        
    '''    
    top = (myloss_all - loss0 - boundary) * (myloss_all - loss0 - boundary)
    bot = np.multiply(myloss_all - loss0, myloss_all - loss0)
    r = ((myloss_all - loss0 - boundary)/boundary)
    strength = np.sum(top, axis=1)
    
    sum_to_one_pairs = find_all_sum_to_one_pairs(n_ways)
#     exp_diff = np.array(sum_to_one_pairs)[:,0]*0.1
    cord = []
    circle = []
    cord_sorted_1 = []
    cord_sorted_2 = []
    cord_sorted_3 = []
    cord_sorted_4 = []
    if n_ways > 2:
        cord_sorted_5 = []
        cord_sorted_6 = []
        cord_sorted_7 = []
        cord_sorted_8 = []
        for idx,pair in enumerate(sum_to_one_pairs): 
            cosa = pair[0]/(np.sqrt(pair[0]**2 + pair[1]**2 + pair[2]**2))
            cosb = pair[1]/(np.sqrt(pair[0]**2 + pair[1]**2 + pair[2]**2))
            cosc = pair[2]/(np.sqrt(pair[0]**2 + pair[1]**2 + pair[2]**2))
            dega = np.arccos(cosa)
            degb = np.arccos(cosb)
            degc = np.arccos(cosc)
#           iterate in 111, 110, 101, 100, 011, 010, 001, 000
            l = [1, -1]
            idx2 = 0
            for d in list(itertools.product(l, repeat=3)):
                dis = boundary + emp_diff[pair_idx][idx*8+idx2]
                cord.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]])
                circle.append([boundary*np.cos(dega)*d[0], boundary*np.cos(degb)*d[1], boundary*np.cos(degc)*d[2]])
                cord_sorted_1.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 0 else None   
                cord_sorted_2.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 1 else None
                cord_sorted_3.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 2 else None                    
                cord_sorted_4.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 3 else None
                cord_sorted_5.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 4 else None   
                cord_sorted_6.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 5 else None
                cord_sorted_7.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 6 else None                    
                cord_sorted_8.append([dis*np.cos(dega)*d[0], dis*np.cos(degb)*d[1], dis*np.cos(degc)*d[2]]) if idx2 == 7 else None
                idx2 = idx2 + 1
#         cord_sorted_1.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_2.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_3.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_4.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_5.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_6.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_7.sort(key=lambda c:(c[0], c[1]))
#         cord_sorted_8.sort(key=lambda c:(c[0], c[1]))
        volumn_total = Integral_Approximation_Double(cord_sorted_1) + Integral_Approximation_Double(cord_sorted_2) + Integral_Approximation_Double(cord_sorted_3) + Integral_Approximation_Double(cord_sorted_4) + Integral_Approximation_Double(cord_sorted_5) + Integral_Approximation_Double(cord_sorted_6) + Integral_Approximation_Double(cord_sorted_7) + Integral_Approximation_Double(cord_sorted_8)
        volumn_ball = (4/3)*np.pi*boundary*boundary*boundary
        volumn_ratio = (volumn_total/volumn_ball)
        return strength, cord, circle, volumn_ratio, r
    else:
        for idx,pair in enumerate(sum_to_one_pairs):
            deg = (np.arctan2(pair[0], pair[1]))
            for i in range(4):
                dis = boundary + emp_diff[pair_idx][idx*4+i]
                if i == 0:
                    deg = deg
                if i == 1:
                    deg = deg+np.pi*.5                    
                if i == 2:
                    deg = deg+np.pi
                if i == 3:
                    deg = deg-np.pi*.5
                x = dis*np.cos(deg)
                y = dis*np.sin(deg)

                
                cord.append([x, y])
                circle.append([boundary*np.cos(deg), boundary*np.sin(deg)])
                cord_sorted_1.append([x, y]) if i == 0 else None   
                cord_sorted_2.append([x, y]) if i == 1 else None
                cord_sorted_3.append([x, y]) if i == 2 else None                    
                cord_sorted_4.append([x, y]) if i == 3 else None
                           
        cord_sorted_1.sort(key=lambda c:(c[0]))
        cord_sorted_2.sort(key=lambda c:(c[0]))
        cord_sorted_3.sort(key=lambda c:(c[0]))
        cord_sorted_4.sort(key=lambda c:(c[0]))
        # Integral Approximation
        area_total = Integral_Approximation(cord_sorted_1) + Integral_Approximation(cord_sorted_2) + Integral_Approximation(cord_sorted_3) + Integral_Approximation(cord_sorted_4)
        area_circle = np.pi*boundary*boundary
        area_ratio = area_total/area_circle
        return strength, cord, circle, area_ratio, r

# %%
e_set_test = [0.01, 0.015, 0.02, 0.05, 0.1, 0.15, 0.2, 0.3, 0.5, 1]
for i,e in enumerate(e_set_test):
#     print(strength_all[i],e,r_all[i])
    print(strength_all[i+1]/strength_all[i])
# Out:
# [1.84021603 1.86129968 1.95584607 1.79933036 1.85455869 2.07335908
#  2.08186423 1.99696513 2.05122166 2.2384392  2.14270713 2.21544482
#  2.14504096 2.20973    2.11595949]
# [1.58194381 1.56393057 1.63414117 1.53842306 1.56583681 1.69778321
#  1.70258089 1.6655678  1.68777176 1.76918406 1.73093417 1.76216043
#  1.73163722 1.75692998 1.71870949]
# [4.66348938 4.07935022 4.95971023 3.97876265 4.16604769 5.59449539
#  5.6582862  5.41784868 5.51604571 6.08260774 5.86787931 6.08842725
#  5.87105268 5.98831643 5.76288891]
# [3.15935345 2.70613167 3.22848362 2.68828245 2.77559824 3.68733142
#  3.74235559 3.67680274 3.65430872 3.82849147 3.81138309 3.8695807
#  3.81736801 3.79314658 3.7615935 ]
# [1.87124542 1.73189043 1.88392077 1.71559558 1.75072951 2.11833789
#  2.14660578 2.1302293  2.10817678 2.15619909 2.16421914 2.17351113
#  2.17167512 2.14591096 2.14723259]
# [1.51715332 1.46186077 1.5202831  1.44130252 1.46455608 1.68701703
# ...

# %%
strength_all
# Out:
# [array([2.68053625e-05, 6.19256342e-05, 2.91266671e-05, 2.48022385e-05,
#         8.27488568e-06, 1.27151052e-04, 5.89059560e-04, 6.57420111e-04,
#         2.09833793e-04, 2.05258525e-04, 3.29997754e-04, 1.58485906e-04,
#         8.62826949e-04, 3.05479933e-04, 3.90017150e-04]),
#  array([4.93276578e-05, 1.15262163e-04, 5.69672775e-05, 4.46274208e-05,
#         1.53462611e-05, 2.63629789e-04, 1.22634203e-03, 1.31284503e-03,
#         4.30415620e-04, 4.59458728e-04, 7.07088542e-04, 3.51116778e-04,
#         1.85079915e-03, 6.75028172e-04, 8.25260491e-04]),
#  array([7.80335830e-05, 1.80262020e-04, 9.30925732e-05, 6.86558534e-05,
#         2.40297405e-05, 4.47586229e-04, 2.08794650e-03, 2.18663242e-03,
#         7.26443329e-04, 8.12867056e-04, 1.22392372e-03, 6.18724092e-04,
#         3.20491269e-03, 1.18597723e-03, 1.41838303e-03]),
#  array([0.00036391, 0.00073535, 0.00046171, 0.00027317, 0.00010011,
#         0.00250402, 0.0118142 , 0.01184684, 0.00400709, 0.00494435,
# ...

# %%
strength_all = []
for i,e in enumerate([0.01, 0.015, 0.02, 0.05, 0.1, 0.15, 0.2, 0.3, 0.5, 1]):
    loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(sm.add_constant(X_test)),epsilon=e, regression=False)
    myloss_all_2, diff_all_2 = Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_all_set[i], loss0, bound_f, regression=False)
    strength, cor_test_2, circle_test_2, ratio, r = feature_interaction_strength(diff_all_2, myloss_all_2, 2, bound_f, 11, loss0)
    print(ratio)
    strength_all.append(strength)
# Out:
# 1.1081441061991133e+00
# 1.1166717199074458e+00
# 1.1144817938226954e+00
# 1.1044089701912247e+00
# 1.1141805709654173e+00
# 1.1000472171002094e+00
# 1.0970975974182182e+00
# 1.0734342144169005e+00
# 1.0346743015384277e+00
# 9.783870807307407e-01

# %%
# r_all = []
for i,e in enumerate([0.01, 0.015, 0.02, 0.05, 0.1, 0.15, 0.2]):
    loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(sm.add_constant(X_test)),epsilon=e, regression=False)
    myloss_all_2, diff_all_2 = Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_all_set[i], loss0, bound_f, regression=False)
    strength, cor_test_2, circle_test_2, ratio, r = feature_interaction_strength(diff_all_2, myloss_all_2, 2, bound_f, 11, loss0)

#     r_all.append(r)
    feature_interaction_vis_2D(circle_test_2, cor_test_2, bound_f, 11)

# %%
def feature_interaction_vis_2D(circle_exp, circle_emp, boundary, pair_idx):
    fig = plt.figure(figsize=[6,6])
    ax = fig.add_subplot(111)
    circle_emp.sort(key=lambda c:np.arctan2(c[0], c[1]))
    circle_emp.append(circle_emp[0])
    circle_exp.sort(key=lambda c:np.arctan2(c[0], c[1]))
    circle_exp.append(circle_exp[0])
    ax.plot(np.array(circle_emp)[:,0], np.array(circle_emp)[:,1], marker='o', linewidth=2, markersize=2, label='emperial interaction')
    ax.plot(np.array(circle_exp)[:,0], np.array(circle_exp)[:,1], linewidth=1, markersize=1, label='expected interaction')
    ax.fill(np.concatenate((np.array(circle_emp)[:,0], np.array(circle_exp)[:,0][::-1])), np.concatenate((np.array(circle_emp)[:,1], np.array(circle_exp)[:,1][::-1])), alpha=0.5, label='interaction difference')


    ax.add_patch(plt.Circle((0, 0), bound_f, fill=False))
    ax.legend(bbox_to_anchor=(1.0, 1.02), shadow=True)
    ax.set_aspect("equal", adjustable="datalim")
    ax.set_box_aspect(0.5)
    ax.autoscale()
loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(sm.add_constant(X_test)),epsilon=0.01, regression=False)
for i in range(10):
    feature_interaction_vis_2D(e_all_new[i][2], e_all_new[i][1], bound_f, 0)
# Out:
# [5.11904647e-01 1.69685722e+00 7.63416053e-01 5.24726980e-01
#  1.90970314e-01 4.59165582e+00 2.90590088e+02 4.97868636e+01
#  7.49769686e+00 8.22883486e+00 2.40835689e+01 5.82862847e+00
#  9.22471157e+03 1.72015880e+01 2.40650613e+01]
# [4.40681048e-01 1.36580266e+00 6.52196198e-01 4.37870076e-01
#  1.59708761e-01 4.06793849e+00 1.31665844e+02 4.44601461e+01
#  6.81859297e+00 8.18867036e+00 2.08516641e+01 5.71829688e+00
#  1.50467667e+04 1.63781893e+01 2.23271811e+01]
# [4.03538233e-01 1.18744206e+00 5.94554092e-01 3.87729836e-01
#  1.41860250e-01 3.81359164e+00 9.34698816e+01 4.20034958e+01
#  6.48520861e+00 8.15678615e+00 1.93608798e+01 5.65970513e+00
#  1.57461241e+04 1.59617416e+01 2.14738821e+01]
# [3.22672254e-01 7.69725378e-01 4.66586237e-01 2.60062829e-01
#  9.67263616e-02 3.33715676e+00 5.23873450e+01 3.77467704e+01
#  5.84784578e+00 8.00959386e+00 1.67833160e+01 5.53349314e+00
#  5.99020332e+02 1.50911229e+01 1.98547750e+01]
# ...

# %%
r_all=[]
s_all=[]
fig = plt.figure(figsize=[6,6])
ax = fig.add_subplot(111)
for i,e in enumerate([0.01, 0.015, 0.02, 0.05, 0.1, 0.15, 0.2]):
    loss0, bound_f, bound_f_half = find_boundary(y_test, model.predict(sm.add_constant(X_test)),epsilon=e, regression=False)
    myloss_all_2, diff_all_2 = Interaction_effect_all_pairs(X_test, y_test, vlist, 2, model, vt_all_set[i], loss0, bound_f, regression=False)
    r_all.append((myloss_all_2 - loss0)/bound_f)
    strength, cor_test_2, circle_test_2, area, r = feature_interaction_strength(diff_all_2, myloss_all_2, 2, bound_f, 0, loss0)
    s_all.append(strength)
    cor_test_2.sort(key=lambda c:np.arctan2(c[0], c[1]))
    cor_test_2.append(cor_test_2[0])
    circle_test_2.sort(key=lambda c:np.arctan2(c[0], c[1]))
    circle_test_2.append(circle_test_2[0])
    ax.plot(np.array(cor_test_2)[:,0], np.array(cor_test_2)[:,1], marker='o', linewidth=2, markersize=2, label='emperial interaction')
    ax.plot(np.array(circle_test_2)[:,0], np.array(circle_test_2)[:,1], linewidth=1, markersize=1, label='expected interaction')
    ax.fill(np.concatenate((np.array(cor_test_2)[:,0], np.array(circle_test_2)[:,0][::-1])), np.concatenate((np.array(cor_test_2)[:,1], np.array(circle_test_2)[:,1][::-1])), alpha=0.5, label='interaction difference')
    ax.add_patch(plt.Circle((0, 0), bound_f, fill=False))
    ax.legend(bbox_to_anchor=(1.0, 1.02), shadow=True)
    ax.set_aspect("equal", adjustable="datalim")
    ax.set_box_aspect(0.5)
    ax.autoscale()

# %%
r_all
# Out:
# [array([[ 1.02027956,  0.95854921,  0.87151687,  1.237795  ,  1.0125276 ,
#           0.97458957,  0.88012425,  1.21896549,  1.01205427,  0.94978964,
#           0.94900343,  1.19581866,  1.01909422,  0.9427166 ,  0.91856253,
#           1.22331401,  1.02381057,  0.93887398,  0.89751063,  1.24070909,
#           1.02657899,  0.93740137,  0.88296085,  1.251158  ,  1.02703662,
#           0.9416001 ,  0.86850834,  1.25525517,  1.02475787,  0.94813117,
#           0.86789035,  1.24955059,  1.02748033,  0.938283  ,  0.8734197 ,
#           1.25596536],
#         [ 0.92554123,  1.05343811,  1.33706734,  0.71649296,  0.95429882,
#           1.03252253,  1.32178936,  0.73413755,  0.93610986,  1.04946783,
#           1.17289242,  0.85284427,  0.91435523,  1.06594569,  1.23342551,
#           0.79625984,  0.90119803,  1.07510083,  1.27425862,  0.75904527,
#           0.8941168 ,  1.0791232 ,  1.30356204,  0.73365776,  0.89687838,
# ...

# %%
r_all_std = np.std(r_all, axis=2)
r_all_std
# Out:
# array([[0.13242576, 0.20448263, 0.14026317, 0.12861033, 0.07461804,
#         0.29308564, 0.63084156, 0.6649001 , 0.37630003, 0.37237864,
#         0.47215051, 0.32720115, 0.76348114, 0.45428173, 0.51323021],
#        [0.12032555, 0.18602056, 0.13077504, 0.11533745, 0.06781564,
#         0.28133124, 0.60681302, 0.62721433, 0.3594307 , 0.3714164 ,
#         0.4607339 , 0.32466566, 0.74545437, 0.45019157, 0.49777889],
#        [0.11379409, 0.17448647, 0.12538319, 0.1074359 , 0.06367764,
#         0.27491176, 0.59383817, 0.60740785, 0.35025992, 0.37051202,
#         0.45460521, 0.32322362, 0.7357095 , 0.4475355 , 0.48944898],
#        [0.09882946, 0.14081955, 0.11170076, 0.08590726, 0.05200218,
#         0.25996267, 0.56497522, 0.56581058, 0.32900919, 0.36545644,
#         0.44037493, 0.31891499, 0.71298214, 0.43797744, 0.46988022],
#        [0.08806667, 0.11531559, 0.10033701, 0.07040835, 0.04321393,
#         0.24925844, 0.54625567, 0.54224739, 0.31413342, 0.35734482,
# ...

# %%
r_all_std = np.std(r_all, axis=2)
scaler = preprocessing.MinMaxScaler()
for i in r_all_std:
    d = scaler.fit_transform(i.reshape(-1, 1))
    print(d.reshape(len(d),))
# Out:
# [0.08391757 0.18852017 0.09529488 0.07837883 0.         0.31714225
#  0.80745147 0.85689313 0.43794186 0.43224931 0.57708486 0.36666663
#  1.         0.55114534 0.63671891]
# [0.07748952 0.17443648 0.09290997 0.07012852 0.         0.31508765
#  0.79540521 0.82551169 0.43034    0.44802746 0.57983441 0.3790368
#  1.         0.56427697 0.63450217]
# [0.07457452 0.16488628 0.09181938 0.06511337 0.         0.31432159
#  0.78889197 0.80908398 0.42644152 0.45657714 0.58170989 0.38621083
#  1.         0.57118997 0.63355828]
# [0.07084525 0.13437227 0.0903183  0.05129518 0.         0.31462451
#  0.77607957 0.77734339 0.41908534 0.47422657 0.58757115 0.40381377
#  1.         0.58394396 0.63220986]
# [0.06867994 0.11040434 0.08746867 0.04164096 0.         0.31550188
#  0.77027344 0.76413584 0.4148405  0.48100716 0.59167053 0.41370122
#  1.         0.58647556 0.63106235]
# [0.06564819 0.09692927 0.08330475 0.03627465 0.         0.3150205
# ...

# %%
for i in range(15):
    df_describe = pd.DataFrame(np.array(r_all)[:,i,:])
    print(df_describe.describe())
# Out:
#              0         1         2         3         4         5         6   \
# count  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   0.000812 -0.002168 -0.005150  0.006966  0.000694 -0.001914 -0.003908
# std    0.000628  0.002004  0.004728  0.005678  0.000603  0.001964  0.003367
# min    0.000130 -0.005317 -0.012902  0.001525  0.000080 -0.005154 -0.009377
# 25%    0.000257 -0.003541 -0.008141  0.002232  0.000170 -0.003144 -0.006074
# 50%    0.000729 -0.001510 -0.003396  0.005118  0.000554 -0.001137 -0.002723
# 75%    0.001331 -0.000499 -0.001322  0.010942  0.001167 -0.000328 -0.001169
# max    0.001645 -0.000266 -0.000824  0.015774  0.001550 -0.000163 -0.000769
#
#              7         8         9   ...        26        27        28  \
# count  7.000000  7.000000  7.000000  ...  7.000000  7.000000  7.000000
# mean   0.005943  0.000370 -0.000832  ... -0.006099  0.007424  0.000833
# ...

# %%
def perimeter(cord):
    p = 0
    for idx, i in enumerate(cord):
        x = i[0]
        y = i[1]
        if idx > 0:
            p = p+np.sqrt((x-prev_x)**2 + (y-prev_y)**2)
        prev_x = x
        prev_y = y
    return p
perimeter(circle_test_2)
# Out:
# 0.8046817034533801

# %%
for i in range(len(r_all)):
    print(r_all[i]-r_all[i+1])
# Out:
# [0.00364619 0.00163057 0.00015839 0.0030921  0.00112997 0.00107336
#  0.00072087 0.01093246 0.00371627 0.00043086 0.00123517 0.00071217
#  0.00073938 0.00060759 0.00392413]
# [0.00196428 0.00119275 0.00017125 0.00163948 0.00068101 0.00074917
#  0.00071482 0.00576751 0.00216014 0.00043026 0.00076064 0.00054618
#  0.00066442 0.00061133 0.00219307]
# [0.00449408 0.00439095 0.00084658 0.00381473 0.00189758 0.00314678
#  0.00388165 0.01312921 0.00620393 0.00259008 0.00323056 0.00282539
#  0.00390627 0.00345743 0.00628971]
# [0.00305775 0.00361662 0.0011914  0.0021175  0.00134001 0.00412978
#  0.00601164 0.00922756 0.00610216 0.00405789 0.00431029 0.00431818
#  0.00617278 0.005342   0.00615878]
# [0.00184515 0.00205079 0.00090008 0.00100156 0.00072652 0.00358159
#  0.00553313 0.00666473 0.00489973 0.00375095 0.00392474 0.00410558
#  0.00578795 0.0048688  0.00505432]
# [0.0012767  0.00137504 0.00066392 0.0005936  0.00047033 0.00319718
# ...

# %%
for i,e in enumerate([0.01, 0.015, 0.02, 0.05, 0.1, 0.15, 0.2]):
    print(s_all[i])
# Out:
# [2.68053625e-05 6.19256342e-05 2.91266671e-05 2.48022385e-05
#  8.27488568e-06 1.27151052e-04 5.89059560e-04 6.57420111e-04
#  2.09833793e-04 2.05258525e-04 3.29997754e-04 1.58485906e-04
#  8.62826949e-04 3.05479933e-04 3.90017150e-04]
# [4.93276578e-05 1.15262163e-04 5.69672775e-05 4.46274208e-05
#  1.53462611e-05 2.63629789e-04 1.22634203e-03 1.31284503e-03
#  4.30415620e-04 4.59458728e-04 7.07088542e-04 3.51116778e-04
#  1.85079915e-03 6.75028172e-04 8.25260491e-04]
# [7.80335830e-05 1.80262020e-04 9.30925732e-05 6.86558534e-05
#  2.40297405e-05 4.47586229e-04 2.08794650e-03 2.18663242e-03
#  7.26443329e-04 8.12867056e-04 1.22392372e-03 6.18724092e-04
#  3.20491269e-03 1.18597723e-03 1.41838303e-03]
# [0.00036391 0.00073535 0.00046171 0.00027317 0.00010011 0.00250402
#  0.0118142  0.01184684 0.00400709 0.00494435 0.00718184 0.00376706
#  0.01881621 0.00710201 0.00817398]
# [0.00114972 0.00198996 0.00149063 0.00073435 0.00027786 0.00923315
# ...

# %%
scaler = preprocessing.MinMaxScaler()
for i in s_all:
    d = scaler.fit_transform(i.reshape(-1, 1))
    print(d.reshape(len(d),))
# Out:
# [0.02168443 0.06278231 0.02440083 0.01934037 0.         0.13910933
#  0.67963638 0.75963215 0.23586498 0.23051099 0.3764813  0.17577749
#  1.         0.34779045 0.44671622]
# [0.0185139  0.05443665 0.02267616 0.0159531  0.         0.13527099
#  0.65978036 0.70690933 0.22614002 0.24196343 0.37687825 0.18293606
#  1.         0.35941097 0.44126125]
# [0.01697763 0.04911601 0.02171184 0.01402947 0.         0.13315689
#  0.64885027 0.67987496 0.22082346 0.24799319 0.37722041 0.18695889
#  1.         0.36529087 0.43835417]
# [0.0140948  0.03394098 0.01932043 0.00924639 0.         0.12844074
#  0.62588298 0.62762718 0.20874996 0.25882752 0.3783762  0.19592475
#  1.         0.3741109  0.43138655]
# [0.01218515 0.02392849 0.01694981 0.00637987 0.         0.12516028
#  0.61404247 0.60489612 0.20077135 0.26067651 0.37868153 0.19984569
#  1.         0.372619   0.42584363]
# [0.0107069  0.01903473 0.01493084 0.00497344 0.         0.12265133
# ...

# %%
vlist = ["age", "race", "prior", "gender", "juvenilecrime", "currentcharge"]
